# %%
# Webscrapping 
import requests
from bs4 import BeautifulSoup
import string

# %%
url = "https://www.fxstreet.com/news?q=&hPP=17&idx=FxsIndexPro&p=0&dFR%5BTags%5D%5B0%5D=EURUSD"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find('main', class_ = "fxs_flex_col")#.find_all('h4')
    print(soup)
# Out:
#  <!DOCTYPE html>
# ...

# %%
def scrape_fxstreet(url):
    response = requests.get(url)
    if response.status_code == 200:
        wiki_text = ""
        soup = BeautifulSoup(response.text, 'html.parser')
        paragraphs = soup.find('div', {'id': 'mw-content-text'}).find_all('p')
        for paragraph in paragraphs:
            wiki_text += " " + paragraph.text
        return wiki_text
    else:
        return None
